# %%
##################################### Genetic Algorithm Demo #############################################
import matplotlib.pyplot as plt 
import numpy
import ga_min   # import GA.py module
# %matplotlib inline

"""
The y=target is to maximize/minimize this equation ASAP:
    y = w1x1+w2x2+w3x3+w4x4+w5x5
    where (x1,x2,x3,x4,x5,x6)=(4,-2,3.5,5,-11)
    What are the best values for the 6 weights w1 to w5?
    We are going to use the genetic algorithm for the best possible values after a number of generations.
    OR,
    a + 2b + 3c + 4d = 30
    y = a + 2b + 3c + 4d - 30
    a = ? b = ? c = ? d = ?
"""

# Inputs of the equation.
equation_inputs = [1,2,3,4]

# Number of the weights we are looking to optimize.
num_weights = len(equation_inputs)

"""
Genetic algorithm parameters:
    Mating pool size
    Population size
"""
sol_per_pop = 10
cr=0.8
num_parents_mating = round(sol_per_pop*cr)

# Defining the population size.
# The population will have sol_per_pop chromosome where each chromosome has num_weights genes.
pop_size = (sol_per_pop,num_weights) 
#Creating the initial population.
new_population = numpy.random.uniform(low=0, high=30, size=pop_size)   # 0 to 30
print('Initial Population:\n',new_population,'\n')

fig, ax = plt.subplots()

num_generations = 1000   # Max Iteration
for generation in range(num_generations):
    # print("\nGeneration: ", generation)
    # Measing the fitness of each chromosome in the population.
    fitness = ga_min.cal_pop_fitness(equation_inputs, new_population)

    # Selecting the best parents in the population for mating.
    parents = ga_min.select_mating_pool(new_population, fitness, 
                                      num_parents_mating)

    # Generating next generation using crossover.
    offspring_crossover = ga_min.crossover(parents,
                                       offspring_size=(pop_size[0]-parents.shape[0], num_weights))

    # Adding some variations to the offsrping using mutation.
    offspring_mutation = ga_min.mutation(offspring_crossover)

    # Creating the new population based on the parents and offspring.
    new_population[0:parents.shape[0], :] = parents
    new_population[parents.shape[0]:, :] = offspring_mutation
    new_population = numpy.absolute(new_population)
    
    # The best result in the current iteration.
    print("Best result: ", numpy.min(numpy.sum(new_population*equation_inputs, axis=1)))

    ax.scatter(new_population[:, 0], new_population[:, 1], c = 'blue', s = 12)
       
ax.set_xlim((0, 30)) 
ax.set_ylim((0, 30)) 
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title("{} vs {}")
# set a title and labels
ax.set_title('Search Space')

# Getting the best solution after iterating finishing all generations.
#At first, the fitness is calculated for each solution in the final generation.
fitness = ga_min.cal_pop_fitness(equation_inputs, new_population)
# Then return the index of that solution corresponding to the best fitness.
best_match_idx = numpy.where(fitness == numpy.min(fitness))   #min

print("\nLast Population:\n")
print(new_population)
print("\nLast Fitness:\n")
print(fitness)
print("\nBest solution: ", new_population[best_match_idx, :])
print("Best solution fitness: ", fitness[best_match_idx])
# Out:
# Initial Population:
#  [[13.42201775 25.74765987 12.4759667  28.77269483]
#  [15.81008121  4.18638444  5.06331301  6.86347553]
#  [13.15201289  4.01923145  1.92513148 29.00916004]
#  [ 1.19906568 13.26741835 10.14372956 22.95031759]
#  [ 5.41881698 19.00511527 29.56679636 20.748961  ]
#  [17.49248743 11.10177475 19.04939572 12.0406964 ]
#  [20.21813547 14.60407492 25.43507561 10.08830864]
#  [29.92453115  5.44016887  2.60536021  2.99060252]
#  [12.41887409  0.51440956 25.14281539 16.27863101]
#  [23.34767794  4.71774088 29.89140991 21.80493812]]
#
# Best result:  60.58335962574759
# Best result:  60.58335962574759
# Best result:  60.58335962574759
# Best result:  60.58335962574759
# Best result:  60.58335962574759
# Best result:  60.58335962574759
# Best result:  60.58335962574759
# Best result:  60.58335962574759
# Best result:  60.58335962574759
# Best result:  60.58335962574759
# Best result:  59.708640322368296
# Best result:  43.33092471863718
# Best result:  40.749930191821704
# ...

# %%
##################################### Genetic Algorithm Demo #############################################
import matplotlib.pyplot as plt 
import numpy
import ga   # import GA.py module
# %matplotlib inline

"""
The y=target is to maximize/minimize this equation ASAP:
    y = w1x1+w2x2+w3x3+w4x4+w5x5
    where (x1,x2,x3,x4,x5,x6)=(4,-2,3.5,5,-11)
    What are the best values for the 6 weights w1 to w5?
    We are going to use the genetic algorithm for the best possible values after a number of generations.
    OR,
    a + 2b + 3c + 4d = 30
    y = a + 2b + 3c + 4d - 30
    a = ? b = ? c = ? d = ?
"""

# Inputs of the equation.
equation_inputs = [1,2,3,4]

# Number of the weights we are looking to optimize.
num_weights = len(equation_inputs)

"""
Genetic algorithm parameters:
    Mating pool size
    Population size
"""
sol_per_pop = 10
cr=0.8
num_parents_mating = round(sol_per_pop*cr)

# Defining the population size.
# The population will have sol_per_pop chromosome where each chromosome has num_weights genes.
pop_size = (sol_per_pop,num_weights) 
#Creating the initial population.
new_population = numpy.random.uniform(low=0, high=30, size=pop_size)   # 0 to 30
print('Initial Population:\n',new_population,'\n')

fig, ax = plt.subplots()

num_generations = 1000   # Max Iteration
for generation in range(num_generations):
    # print("\nGeneration: ", generation)
    # Measing the fitness of each chromosome in the population.
    fitness = ga.cal_pop_fitness(equation_inputs, new_population)

    # Selecting the best parents in the population for mating.
    parents = ga.select_mating_pool(new_population, fitness, 
                                      num_parents_mating)

    # Generating next generation using crossover.
    offspring_crossover = ga.crossover(parents,
                                       offspring_size=(pop_size[0]-parents.shape[0], num_weights))

    # Adding some variations to the offsrping using mutation.
    offspring_mutation = ga.mutation(offspring_crossover)

    # Creating the new population based on the parents and offspring.
    new_population[0:parents.shape[0], :] = parents
    new_population[parents.shape[0]:, :] = offspring_mutation
    new_population = numpy.absolute(new_population)
    
    # The best result in the current iteration.
    print("Best result: ", numpy.min(numpy.sum(new_population*equation_inputs, axis=1)))

    ax.scatter(new_population[:, 0], new_population[:, 1], c = 'blue', s = 12)
       
ax.set_xlim((0, 30)) 
ax.set_ylim((0, 30)) 
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title("{} vs {}")
# set a title and labels
ax.set_title('Search Space')

# Getting the best solution after iterating finishing all generations.
#At first, the fitness is calculated for each solution in the final generation.
fitness = ga.cal_pop_fitness(equation_inputs, new_population)
# Then return the index of that solution corresponding to the best fitness.
best_match_idx = numpy.where(fitness == numpy.min(fitness))   #min

print("\nLast Population:\n")
print(new_population)
print("\nLast Fitness:\n")
print(fitness)
print("\nBest solution: ", new_population[best_match_idx, :])
print("Best solution fitness: ", fitness[best_match_idx])
# Out:
# Initial Population:
#  [[17.90520274 26.76637813 20.28073858  1.57394694]
#  [ 2.51242704 12.63849    21.43504523 11.231158  ]
#  [25.51260545 13.70858119 17.95713067 28.76294376]
#  [15.6202263  28.87526929  9.86993124 20.82287901]
#  [25.82630303 18.71742818  2.52692824 29.61845368]
#  [15.76329797  5.48983055  8.50064759  7.56834931]
#  [24.19511542 14.09687414 10.29604026 26.65821487]
#  [ 8.86400491 17.21973761 14.67035227  5.03054054]
#  [20.25161561 14.86059602 22.06737127 11.95553173]
#  [ 7.022982    0.65515288  0.17084695 15.58040297]]
#
# Best result:  107.43669907679963
# Best result:  138.57596250385865
# Best result:  179.09174174281787
# Best result:  186.27207461842056
# Best result:  189.31575885562052
# Best result:  190.32270631492847
# Best result:  193.7530127978754
# Best result:  194.12592818762556
# Best result:  194.46589271319309
# Best result:  196.24509836349586
# Best result:  193.5530569994343
# Best result:  196.56510309896728
# ...
